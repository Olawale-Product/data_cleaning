# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

x1 = [1,2,3]
y1 = [2,4,1]
plt.plot(x1,y1, label = " line1")
plt.show()

# %%
# Generating X and Y points to plot
x1 = np.arange(0, 10*np.pi, 0.1)
y1 = np.cos(x1)


plt.plot(x1,y1, label=" Cosine Function")
plt.legend()
plt.xlabel("Angle")  #naming the x axis
plt.ylabel("Amplitude") #naming the y axis

plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\hp\Desktop\Lero\exploratory_data_analysis\eda.ipynb Cell 2' in <cell line: 11>()
#       <a href='vscode-notebook-cell:/c%3A/Users/hp/Desktop/Lero/exploratory_data_analysis/eda.ipynb#ch0000001?line=7'>8</a> plt.xlabel("Angle")  #naming the x axis
#       <a href='vscode-notebook-cell:/c%3A/Users/hp/Desktop/Lero/exploratory_data_analysis/eda.ipynb#ch0000001?line=8'>9</a> plt.ylabel("Amplitude") #naming the y axis
# ---> <a href='vscode-notebook-cell:/c%3A/Users/hp/Desktop/Lero/exploratory_data_analysis/eda.ipynb#ch0000001?line=10'>11</a> plot.show()
#
# NameError: name 'plot' is not defined
